# %%
import raman_analyzer.analyzer as raman
import numpy as np

# %%
d=[1300,1400,4]
g=[1500,1700,7]
twod=[2600,2800,7]
noise = [1700,2200]
a,filter = raman.ratio_calculator('/home/flyingchow/raman/9thLP',6,d,g,twod,noise)

# %%
a,b,c,d,name,e = raman.raman_batch('/home/flyingchow/raman/9thLP',1200,3000,7,show=True,export=False,noise_min=1700,noise_max=1900)
